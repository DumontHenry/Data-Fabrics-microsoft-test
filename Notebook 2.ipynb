# %%
import pandas as pd 
df = pd.read_csv("https://raw.githubusercontent.com/plotly/datasets/master/titanic.csv")
display(df)
# Out:
# StatementMeta(, e3e9fba2-7f37-4260-8dc3-9df4a5030cd7, 6, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, d4885eb7-4cc0-4760-bd5e-f3ab0c13255d)

# %%
# Code generated by Data Wrangler for pandas DataFrame
# Data Wrangler can be find on Data Fabrics notebook / select Home / click on Data Wrangler / select Dataframes 

def clean_data(df):
    # Convert text to uppercase in column: 'Name'
    df['Name'] = df['Name'].str.upper()
    # Replace missing values with -1 in column: 'Age'
    df = df.fillna({'Age': -1})
    # Change column type to int64 for columns: 'Survived', 'PassengerId' and 2 other columns
    df = df.astype({'Survived': 'int64', 'PassengerId': 'int64', 'Pclass': 'int64', 'Age': 'int64'})
    # Replace missing values with "-" in column: 'Cabin'
    df = df.fillna({'Cabin': "-"})
    # Filter rows based on column: 'Sex'
    df = df[df['Sex'] == "female"]
    # Split text using string ',' in column: 'Name'
    loc_0 = df.columns.get_loc('Name')
    df_split = df['Name'].str.split(pat=',', expand=True).add_prefix('Name_')
    df = pd.concat([df.iloc[:, :loc_0], df_split, df.iloc[:, loc_0:]], axis=1)
    df = df.drop(columns=['Name'])
    # Rename column 'Name_0' to 'Last Name'
    df = df.rename(columns={'Name_0': 'Last Name'})
    # Rename column 'Name_1' to 'Firstname'
    df = df.rename(columns={'Name_1': 'Firstname'})
    # Split text using string '. ' in column: 'Firstname'
    loc_0 = df.columns.get_loc('Firstname')
    df_split = df['Firstname'].str.split(pat='\\. ', expand=True).add_prefix('Firstname_')
    df = pd.concat([df.iloc[:, :loc_0], df_split, df.iloc[:, loc_0:]], axis=1)
    df = df.drop(columns=['Firstname'])
    # Rename column 'Firstname_0' to 'Title'
    df = df.rename(columns={'Firstname_0': 'Title'})
    # Rename column 'Firstname_1' to 'Firstname'
    df = df.rename(columns={'Firstname_1': 'Firstname'})
    return df

df_female = clean_data(df.copy())
df_female.head()
# Out:
# StatementMeta(, e3e9fba2-7f37-4260-8dc3-9df4a5030cd7, 144, Finished, Available, Finished)
#    PassengerId  Survived  Pclass  Last Name  Title  \
# 1            2         1       1    CUMINGS    MRS
# 2            3         1       3  HEIKKINEN   MISS
# 3            4         1       1   FUTRELLE    MRS
# 8            9         1       3    JOHNSON    MRS
# 9           10         1       2     NASSER    MRS
#
#                                Firstname     Sex  Age  SibSp  Parch  \
# 1  JOHN BRADLEY (FLORENCE BRIGGS THAYER)  female   38      1      0
# 2                                  LAINA  female   26      0      0
# 3          JACQUES HEATH (LILY MAY PEEL)  female   35      1      0
# 8    OSCAR W (ELISABETH VILHELMINA BERG)  female   27      0      2
# 9                 NICHOLAS (ADELE ACHEM)  female   14      1      0
#
#              Ticket     Fare Cabin Embarked
# 1          PC 17599  71.2833   C85        C
# 2  STON/O2. 3101282   7.9250     -        S
# ...

# %%
# Code generated by Data Wrangler for pandas DataFrame
# Data Wrangler can be find on Data Fabrics notebook / select Home / click on Data Wrangler / select Dataframes 

def clean_data(df):
    # Convert text to uppercase in column: 'Name'
    df['Name'] = df['Name'].str.upper()
    # Replace missing values with -1 in column: 'Age'
    df = df.fillna({'Age': -1})
    # Change column type to int64 for columns: 'Survived', 'PassengerId' and 2 other columns
    df = df.astype({'Survived': 'int64', 'PassengerId': 'int64', 'Pclass': 'int64', 'Age': 'int64'})
    # Replace missing values with "-" in column: 'Cabin'
    df = df.fillna({'Cabin': "-"})
    # Filter rows based on column: 'Sex'
    df = df[df['Sex'] == "male"]
    # Split text using string ',' in column: 'Name'
    loc_0 = df.columns.get_loc('Name')
    df_split = df['Name'].str.split(pat=',', expand=True).add_prefix('Name_')
    df = pd.concat([df.iloc[:, :loc_0], df_split, df.iloc[:, loc_0:]], axis=1)
    df = df.drop(columns=['Name'])
    # Rename column 'Name_0' to 'Last Name'
    df = df.rename(columns={'Name_0': 'Last Name'})
    # Rename column 'Name_1' to 'Firstname'
    df = df.rename(columns={'Name_1': 'Firstname'})
    # Split text using string '. ' in column: 'Firstname'
    loc_0 = df.columns.get_loc('Firstname')
    df_split = df['Firstname'].str.split(pat='\\. ', expand=True).add_prefix('Firstname_')
    df = pd.concat([df.iloc[:, :loc_0], df_split, df.iloc[:, loc_0:]], axis=1)
    df = df.drop(columns=['Firstname'])
    # Rename column 'Firstname_0' to 'Title'
    df = df.rename(columns={'Firstname_0': 'Title'})
    # Rename column 'Firstname_1' to 'Firstname'
    df = df.rename(columns={'Firstname_1': 'Firstname'})

    return df

df_male = clean_data(df.copy())
df_male.head()
# Out:
# StatementMeta(, e3e9fba2-7f37-4260-8dc3-9df4a5030cd7, 143, Finished, Available, Finished)
#    PassengerId  Survived  Pclass Last Name    Title      Firstname   Sex  Age  \
# 0            1         0       3    BRAUND       MR    OWEN HARRIS  male   22
# 4            5         0       3     ALLEN       MR  WILLIAM HENRY  male   35
# 5            6         0       3     MORAN       MR          JAMES  male   -1
# 6            7         0       1  MCCARTHY       MR      TIMOTHY J  male   54
# 7            8         0       3   PALSSON   MASTER  GOSTA LEONARD  male    2
#
#    SibSp  Parch     Ticket     Fare Cabin Embarked
# 0      1      0  A/5 21171   7.2500     -        S
# 4      0      0     373450   8.0500     -        S
# 5      0      0     330877   8.4583     -        Q
# 6      0      0      17463  51.8625   E46        S
# 7      3      1     349909  21.0750     -        S
